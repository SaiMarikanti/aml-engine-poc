# %%
# COMMAND ----------

CATALOG = "aml_engine"
SCHEMA = "aml_poc"

S3_BASE_PATH = "s3://zubair-s3-demo/raw_dataset/aml"
S3_DELTA_PATH = f"{S3_BASE_PATH}/delta_tables"

# %%
# COMMAND ---------- Bronze Tables

spark.sql(f"""
CREATE TABLE IF NOT EXISTS {CATALOG}.{SCHEMA}.bronze_accounts
USING DELTA
LOCATION '{S3_DELTA_PATH}/bronze_accounts'
""")

spark.sql(f"""
CREATE TABLE IF NOT EXISTS {CATALOG}.{SCHEMA}.bronze_transactions
USING DELTA
LOCATION '{S3_DELTA_PATH}/bronze_transactions'
""")

spark.sql(f"""
CREATE TABLE IF NOT EXISTS {CATALOG}.{SCHEMA}.bronze_alerts
USING DELTA
LOCATION '{S3_DELTA_PATH}/bronze_alerts'
""")

# %%
# COMMAND ---------- Silver Table

spark.sql(f"""
CREATE TABLE IF NOT EXISTS {CATALOG}.{SCHEMA}.silver_accounts
USING DELTA
LOCATION '{S3_DELTA_PATH}/silver_accounts'
""")

# %%
spark.sql(f"""
CREATE TABLE IF NOT EXISTS {CATALOG}.{SCHEMA}.silver_transactions
USING DELTA
LOCATION '{S3_DELTA_PATH}/silver_transactions'
""")

spark.sql(f"""
CREATE TABLE IF NOT EXISTS {CATALOG}.{SCHEMA}.silver_alerts
USING DELTA
LOCATION '{S3_DELTA_PATH}/silver_alerts'
""")

# %%
# COMMAND ---------- Verify Once

display(
    spark.sql(f"""
        SHOW TABLES IN {CATALOG}.{SCHEMA}
    """)
)

# %%
spark.sql(f"""
CREATE TABLE IF NOT EXISTS {CATALOG}.{SCHEMA}.rule_results
USING DELTA
LOCATION '{S3_DELTA_PATH}/rule_results'
""")


spark.sql(f"""
CREATE TABLE IF NOT EXISTS {CATALOG}.{SCHEMA}.rule_transaction_scores
USING DELTA
LOCATION '{S3_DELTA_PATH}/rule_transaction_scores'
""")

# %%
spark.sql(f"""
CREATE TABLE IF NOT EXISTS {CATALOG}.{SCHEMA}.graph_account_features
USING DELTA
LOCATION '{S3_DELTA_PATH}/graph_account_features'
""")

spark.sql(f"""
CREATE TABLE IF NOT EXISTS {CATALOG}.{SCHEMA}.graph_results
USING DELTA
LOCATION '{S3_DELTA_PATH}/graph_results'
""")

# %%
spark.sql(f"""
CREATE TABLE IF NOT EXISTS {CATALOG}.{SCHEMA}.ml_training_data
USING DELTA
LOCATION '{S3_DELTA_PATH}/ml_training_data'
""")
