# %%
# %sql
CREATE CATALOG IF NOT EXISTS AML_Engine;
-- 1. Create the POC Schema
CREATE SCHEMA IF NOT EXISTS AML_Engine.aml_poc;

-- 2. Create the Volume to hold raw IBM CSVs
CREATE VOLUME IF NOT EXISTS AML_Engine.aml_poc.raw_landing;

-- 3. Create the Volume for Auto Loader stream checkpoints
CREATE VOLUME IF NOT EXISTS AML_Engine.aml_poc.checkpoints;
